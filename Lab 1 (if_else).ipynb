# %%
#Task 1


a = int(input(''))
b = int(input(' '))

# Inverted comma dileo ja, na dileo ta. Kintu ekta space rekhe input nite chaile 
# inverted comma er bhitore space dile space ashe. inverted comma na dile ashe na.
# string, int jai input nei inverted comma deyar kono dorkar nai.
# Just aage int/ str egula mention korlei oi format ei input nibe.
# kichu mention na korle str e input nibe.

sum = a + b
product = a * b
difference = a - b

print('Sum =', sum)
print('Product =', product)
print('Difference =', difference)
# Out:
# 30
#  2
# Sum = 32
# Product = 60
# Difference = 28

# %%
#Task 2


radius=float(input())

import math   #(math.pi er jonno)note

circumference = 2 * math.pi * radius
print('Circumference is', circumference)

area = math.pi * radius ** 2

# radius * radius (evabeo simply radius ke square kora jay but kokhono boro
#kono power thakle she khetre uporer method mathay rakhbo)

print('Area is', area)
# Out:
# 3.5
# Circumference is 21.991148575128552
# Area is 38.48451000647496

# %%
#Task 3


a = int(input( ))
b = int(input( ))

if a > b:
  print("First is greater")

elif b > a:
  print("Second is greater")

else:
  print("The numbers are equal")

#python negative number er o boro choto bujhe. Er jonno oke amar kichu bujhano lagbe na.
# Out:
# -33
# -3
# Second is greater

# %%
#Task 4


a = int(input(" "))
b = int(input(" "))

if a > b or a == b:
  sub1 = a - b
  print(sub1)

# a==b elif er moddhe dileo problem hoto na.

elif b > a :
  sub2 = b-a
  print(sub2)
# Out:
#  5
#  5
# 0

# %%
#Task 5


a = int(input(" "))

if a % 2 == 0:
  print("The number is even")

else:
  print("The number is odd")
# Out:
#  -44
# The number is even

# %%
#Task 6

a = int(input(' '))

if a % 2 == 0 and a % 5 == 0 :
    print(a)

elif a % 2 == 0 :
    print(a)

elif a % 5 == 0 :
    print(a)

else :
    print('Not a multiple we want')
# Out:
#  17
# Not a multiple we want

# %%
# Task 6 (OR)

a = int(input(""))

if a % 2 == 0 or a % 5 == 0:
  print(a)

else:
  print("Not a multiple of 2 OR 5")
# Out:
# 3
# Not a multiple of 2 OR 5

# %%
#Task 7


a=int(input(" "))

if a%2==0 and a%5==0: 
  print("Multiple of 2 and 5 both")

elif a%2==0 or a%5==0:
  print(a)

else:
  print("Not a multiple we want")
# Out:
#  17
# Not a multiple we want

# %%
#Task 8

a=int(input(" "))

if a % 2 == 0 and a % 5 == 0:
  print(a)

else:
  print("Not multiple of 2 and 5 both")
# Out:
#  6
# Not multiple of 2 and 5 both

# %%
#Task 9 (NICHE OR AREKVABE ASE)..(ekhane variable beshi)


a=int(input(' '))

hour= a // 3600 
print('Hours:',hour, end=' ')

second= a % 3600

b= second

minute= second // 60
print('Minutes:',minute, end=' ')     

second= b % 60
print('Seconds:',second, end=' ')
# Out:
#  500
# Hours: 0 Minutes: 8 Seconds: 20

# %%
#Task 9 (OR)..(NICHE AREKTA)..(variable komay disi)


a=int(input(' '))

hour= a // 3600 
print('Hours:',hour, end=' ')

second= a % 3600



minute= second // 60
print('Minutes:',minute, end=' ')     

second= second % 60
print('Seconds:',second, end=' ')
# Out:
#  500
# Hours: 0 Minutes: 8 Seconds: 20

# %%
#Task 9 (OR)..(understandable variable)

given_sec = int(input())

hour = given_sec // 3600
print('Hours:',hour, end=' ')

remaining_sec = given_sec % 3600

min = remaining_sec//60
print('Minute:' ,min, end=' ')

sec= remaining_sec % 60
print('Second:' ,sec, end=' ')
# Out:
# 500
# Hours: 0 Minute: 8 Second: 20

# %%
#Task 10


a=int(input(' '))

if a < 0:
  print('Hour cannot be negative')

elif a < 40 or a == 40:
  salary1= a * 200
  print(salary1)

elif a > 40 and a < 168:
  salary2= 8000 + (a-40) *300
  print(salary2)

else:
  print('Impossible to work more than 168 hours weekly')
# Out:
#  170
# Impossible to work more than 168 hours weekly

# %%
#Task 10 (OR)


a=int(input(' '))

if a > 0 and a < 168:
  
  if a < 40 or a == 40:
    salary1= a * 200
    print(salary1)

  elif a > 40 and a < 168:
    salary2= 8000 + (a-40) *300
    print(salary2)

else:
  if a < 0:
    print("Hour cannot be negative")

  elif a > 168:
    print('Impossible to work more than 168 hours weekly')
# Out:
#  170
# Impossible to work more than 168 hours weekly

# %%
#Task 11


s=int(input(' '))

if s < 100:
  l= 3000 - 125 * s * s
  print(l)

elif s > 100 or s == 100:
  l= 12000 / ( 4 + ((s ** 2) / 14900 ))
  #---or---  l= 12000 / ( 4 + (s ** 2) / 14900 ) 
  print(l)

# l= 12000 / ( (4 + (s ** 2)) / 14900 )
# evabe extra bracket e rakhle ans mile na. karon 14900 shudhu s^2 er shathe
# bhag..4 er shathe na.
# Out:
#  3
# 1875

# %%
# Task 12


a=int(input(' '))

if a < 0 or a > 23:
  print('Wrong time')

elif a > 3 and a < 7:
  print('Breakfast') 

elif a > 11 and a < 14:
  print('Lunch')

elif a > 15 and a < 18:
  print('Snacks')

elif a > 18 and a < 21:
  print('Dinner')

else:
  print('Patience is a virtue')


# eidhoroner code e aagei code er shoundorjo or short code niye chinta korte
# jabo na. aage emon vabe code ta korbo jeno shobgula condition fullfil kore.
# oi onujayi konta aage konta pore chinta korbo.
# example dhore dhore chinta korbo.
# Out:
#  27
# Wrong time

# %%
# Task 12 (or)

a=int(input(' '))

if a >= 0 and a <= 23:
  
  if a > 3 and a < 7:
    print('Breakfast') 

  elif a > 11 and a < 14:
    print('Lunch')

  elif a > 15 and a < 18:
    print('Snacks')

  elif a > 18 and a < 21:
    print('Dinner')
  
  else:
    print('Patience is a virtue')

else:
  print('Wrong time')
# Out:
#  19
# Dinner

# %%
#Task 13


a=int(input(' '))

if a < 0 or a > 100:
  print('Invalid marks')

elif a > 89:
  print('A')

elif a > 79 and a < 90:
  print('B')

elif a > 69 and a < 80:
  print('C')

elif a > 59 and a < 70:
  print ('D')

elif a > 49 and a < 60:
  print('E')

else:
  print('F')

## or (niche ache)
# Out:
#  49
# F

# %%
#Task 13 (or)


a= int(input( ))

if a < 0 or a > 100:
  print('Invalid marks')

elif a > 89:   # number gulo condition wise serially boro theke choto te jacche.
  print('A')   # aar number gulor majhe kono gap nai TAI eivabe condition deya
               # jay.. and diye range er moto na koreo.
elif a > 79:
  print('B')

elif a > 69:
  print('C')

elif a > 59:
  print('D')

elif a > 49:
  print('E')

else:
  print('F')
# Out:
# 42
# F

# %%
#Task 13 (or)


a=int(input(' '))

if a > 0 and a < 100:
  
  if a > 89:
    print('A')

  elif a > 79 and a < 90:
    print('B')

  elif a > 69 and a < 80:
    print('C')

  elif a > 59 and a < 70:
    print ('D')

  elif a > 49 and a < 60:
    print('E')

  else:
    print('F')

else:
  print('Invalid marks')
# Out:
#  59
# E

# %%
#Task 14


distance_m=int(input(' '))
time_s=int(input(' '))

distance_km= distance_m/1000
time_hr=time_s/3600

velocity= distance_km / time_hr

if velocity < 60:
  print(velocity, 'km/h')
  print('Too slow. Needs more changes.')
  #print(velocity, 'km/h\nToo slow. Needs more changes.')---or
  
elif velocity > 59 and velocity < 91:
  print(velocity, 'km/h')
  print('Velocity is okay. The car is ready!')

elif velocity > 90:
  print(velocity, 'km/h')
  print('Too fast. Only a few changes should suffice.')
# Out:
#  25400
#  3600
# 25.4 km/h
# Too slow. Needs more changes.

# %%
#Task 15


cgpa=float(input(' '))
credit=int(input(' '))

if cgpa >= 3.8 and credit >= 30:

  if cgpa > 3.79 and cgpa < 3.90:
    print('The student is eligible for a waiver of 25 percent.')

  elif cgpa > 3.89 and cgpa < 3.95:
    print('The student is eligible for a waiver of 50 percent.')

  elif cgpa > 3.94 and cgpa < 4.00:
    print ('The student is eligible for a waiver of 75 percent.')

  elif cgpa == 4.00:
    print('The student is eligible for a waiver of 100 percent.')

else:
  print('The student is not eligible for a waiver.')
# Out:
#  3.79
#  24
# The student is not eligible for a waiver.

# %%
#Task 16


p=5
q=6
r=9
sum=0

if (p<12):
  print(r+2)

else:
  print(r+p)

if (q>20):
  print(r+19)

elif (q<=6):
  print(q+3)

else:
  print(p+q+r)

if (r>12):
  print(r)

elif (r==0):
  print(p+q)

else:
  print(p)

if (sum != 0):
  print (3)

else:
  print(sum+32)

if (p>0 and r<10):
  print(p+r)

else:
  print(p-r)
# Out:
# 11
# 9
# 5
# 32
# 14

# %%
#Task 17


var1=var2=var3=var4=var5=var6=False
result1=False
result2=False
result3=False
result4=False
result5=False
result6=False
result7=False
result8=False
result9=False
result10=False

var1 = 4 > 3 - 1
var2= var1 and False
var3= True
var4= False
var5= True
var6= var3 and False
result1=(var1 or var2) and (8*10>45)
print(result1)

result2=(var1 or var2) and (result1 and False)
print(result2)

result3=(var1 and result1) or result2
print(result3)

result4=(var1 or var2) or ((var3 and var1) and False)
print(result4)

result5=(var1 and var2) and (result3 or var1)
print(result5)

result6=((var3 or var2) and not (result5)) or True
print(result6)

result7=(var4 and result1) and ((result1 and False) or True)
print(result7)

result8=((var1 and result3) and (var5 or var6)) and True
print(result8)

result9=((result2 and var2) or (result7 and var1)) and False
print(result9)

result10=not (var1 and True)
print(result10)
# Out:
# True
# False
# True
# True
# False
# True
# False
# True
# False
# False

# %%
#Task 18


var1= False
var2= False
var3= False
var4= False
var5= False
var6= False
result1= False
result2= False
result3= False
result4= False
result5= False
result6= False
result7= False
result8= False
result9= False
result10= False

var1= ((not True) or True) and False
var2= var1 and False
var3= True and not False
var4= False
var5= True
var6= var3 and False
result1= (var1 and var2) and (40%3) > 45 or (var5 and var6)
print(result1)

result2 = (var1 or var2) or (result1 and False)
print(result2)

result3 = (var1 and result1) or result2 or var5
print(result3)

result4 = (var1 or var2) or ((var3 and var1) and False)
print(result4)

result5 = (var1 and var2) and (result3 or var1)
print(result5)

result6 = ((var3 or (not var2)) and (result5)) or True
print(result6)

result7 = (var4 and result1) and ((result1 and False) or True)
print(result7)

result8 = ((var1 and result3) and ((not var5) or var6)) and True
print(result8)

result9 = ((result2 and var2) or ((not result7) and var1)) and not False
print(result9)

result10 = not(var1 and True)
print(result10)
# Out:
# False
# False
# True
# False
# False
# True
# False
# False
# False
# True

# %%
#Task 19
var1 = var2 = var3 = var4 = var5 = var6 = False
result1 = result2 = result3 = result4 = result5 = result6 = False
result7 = result8 = result9 = result10 = False
var1 = (not False or False) and True
var2 = var1 and True
var3 = False and not True
var4 = True
var5 = False
var6 = var3 and True 
result1 = (var1 and var2) and ( 40 % 3 > 45) or (var5 and var6)
print(result1)

result2 = (var1 or var2) or (result1 and False)
print(result2)

result3 = (var1 and result1) or result2 or var5
print(result3)

result4 = (var1 or var2) or ((var3 and var1) and False)
print(result4)

result5 = (var1 and var2) and (result3 or var1)
print(result5)

result6 = ((var3 or not var2) and (result5)) or True
print(result6)

result7 = (var4 and result1) and ((result1 and False) or True)
print(result7)

result8 = ((var1 and result3) and (not var5 or var6)) and True
print(result8)

result9 = ((result2 and var2) or (not result7 and var1)) and not False
print(result9)

result10 = not (var1 and True)
print(result10)
# Out:
# False
# True
# True
# True
# True
# True
# False
# True
# True
# False

# %%
#Task 20

a= int(input( ))

if a % 2 != 0 and a % 5 != 0:
  print(a)

else:
  print('No')
# Out:
# 12
# No

# %%
#Task 21


a= int(input(''))

if a % 2 != 0 or a % 5 != 0:
  print(a)

else:
  print('No')
# Out:
# 14
# 14

# %%
#Task 22


canvas_number= int(input(' '))
paintTube_number= int(input(' '))

total= ((120 * canvas_number)+(75 * paintTube_number)) 


if total == 0 or (total > 0 and total <= 299):
  print('Previous total:',total)
  print('New total after discount:',total)

elif total > 299 and total < 500:
  print('Previous total:',total)
  print('New total after discount:',total-10)

elif total > 499 and total < 750:
  print('Previous total:',total)
  print('New total after discount:',total-20)

elif total > 749 and total < 1000:
  print('Previous total:',total)
  print('New total after discount:',total-50)

else:
  print('Previous total:',total)
  print('New total after discount:',total-150)
# Out:
#  0
#  3
# Previous total: 225
# New total after discount: 225

# %%
#Task 23


a= int(input())

celsius=(a - 32) * 0.56

formatedCelsius= format(celsius,".2f")


if celsius < 20:
  print(formatedCelsius,"degrees C")
  print('Winter')

elif celsius > 19.9 and celsius < 25.00:
  print(formatedCelsius,'degrees C')
  print('Autumn')

elif celsius > 25 and celsius < 30:
  print(formatedCelsius,'degrees C')
  print('Spring')

else:
  print(formatedCelsius,'degrees C')
  print('Summer')
# Out:
# 77
# 25.20 degrees C
# Spring

# %%
###

counter=24

while counter >= -6:

  if counter == -6:
    print(counter,end='')

  else:
    print(counter,end=', ')

  counter= counter-6
# Out:
# 24, 18, 12, 6, 0, -6

# %%
##

counter = -10

while counter <= 20:
  if counter == 20:
    print(counter,end='')

  else:
    print(counter,end=', ')  

  counter += 5
# Out:
# -10, -5, 0, 5, 10, 15, 20

# %%
##

counter =18

while counter <= 63:
  
  if counter == 63:
    print(counter,end='')
  else:
    print(counter,end=', ')  

  counter += 9
# Out:
# 18, 27, 36, 45, 54, 63

# %%
##1(d)

step = 9

for counter in range(18, 63, step):
  if(counter %2 != 0):
    print(-counter, end=', ')
   
  else:
    print(counter, end=', ')

print((counter+step)*(-1))
# Out:
# 18, -27, 36, -45, 54, -63
